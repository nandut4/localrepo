# %%
import pandas as pd
import numpy as np

# %%
np.random.seed(42)
df = pd.DataFrame(np.random.randint(1,100, size = (5,4)), columns = ['Math', 'Science', 'English', 'History'])

# %%
df.head()
# Out:
#    Math  Science  English  History
# 0    52       93       15       72
# 1    61       21       83       87
# 2    75       75       88       24
# 3     3       22       53        2
# 4    88       30       38        2
